# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/college_1.csv')
df1 = pd.read_csv('/content/drive/MyDrive/college_2.csv')

# %%
df
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
df1
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               84 non-null     object
#  1   python             84 non-null     float64
#  2   mysql              84 non-null     float64
#  3   Previous Geekions  84 non-null     int64
#  4   CodeKata Score     84 non-null     int64
#  5   Department         84 non-null     object
#  6   Rising             84 non-null     int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 4.7+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    35 non-null     object
#  1   python                  35 non-null     int64
#  2   python_en               35 non-null     int64
#  3   mysql                   35 non-null     int64
#  4   computational_thinking  35 non-null     int64
#  5   Previous Geekions       35 non-null     int64
#  6   CodeKata Score          35 non-null     int64
#  7   Department              35 non-null     object
#  8   Rising                  35 non-null     int64
# dtypes: int64(7), object(2)
# memory usage: 2.6+ KB

# %%
df['python'] = df['python'].astype(int)
df['mysql'] = df['mysql'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               84 non-null     object
#  1   python             84 non-null     int64
#  2   mysql              84 non-null     int64
#  3   Previous Geekions  84 non-null     int64
#  4   CodeKata Score     84 non-null     int64
#  5   Department         84 non-null     object
#  6   Rising             84 non-null     int64
# dtypes: int64(5), object(2)
# memory usage: 4.7+ KB

# %%
print(df.shape)
print(df1.shape)
# Out:
# (84, 7)
# (35, 9)

# %%
#add two columns to df
df.insert(4,"computational_thinking",0)

# %%
df
# Out:
#               Name  python  mysql  Previous Geekions  computational_thinking  \
# 0        A.Dharani      82     20              24500                       0
# 1      V.JEEVITHA       82     20              21740                       0
# 2      HEMAVATHI.R     100    100              19680                       0
# 3      Mugunthan S     100     47              10610                       0
# 4      Sathammai.S     100      8               8980                       0
# ..             ...     ...    ...                ...                     ...
# 79    KarthikeyanS      45      0                  0                       0
# 80        BARATH.P      29      0                  0                       0
# 81   N.Ajith kumar      82      0                  0                       0
# 82    mohamed nabi       0      0                  0                       0
# 83  yaser ahamed.A       0     27                  0                       0
#
# ...

# %%
frames=[df,df1]
df=pd.concat(frames)
df
# Out:
#              Name  python  mysql  Previous Geekions  computational_thinking  \
# 0       A.Dharani      82     20              24500                       0
# 1     V.JEEVITHA       82     20              21740                       0
# 2     HEMAVATHI.R     100    100              19680                       0
# 3     Mugunthan S     100     47              10610                       0
# 4     Sathammai.S     100      8               8980                       0
# ..            ...     ...    ...                ...                     ...
# 30  praveen raj j      24      0               2380                       0
# 31     AMARNATH D      -1     12               1890                      -1
# 32           bala      32      0               1720                      -1
# 33           XY Z      -1     -1                  0                      -1
# 34      Hariharan      -1     -1                  0                       0
#
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
Exceeded_expectations = df[df['CodeKata Score']>15000]
Exceeded_expectations
# Out:
#             Name  python  mysql  Previous Geekions  computational_thinking  \
# 0      A.Dharani      82     20              24500                       0
# 1    V.JEEVITHA       82     20              21740                       0
# 2    HEMAVATHI.R     100    100              19680                       0
# 0  ASHOK KUMAR K     100     31              19400                       9
#
#    CodeKata Score                              Department  Rising  python_en
# 0           24500        Computer Science and Engineering       0        NaN
# 1           21740        Computer Science and Engineering       0        NaN
# 2           19680        Computer Science and Engineering       0        NaN
# 0           19400  Electronics and Electrical Engineering       0        0.0

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
Reached_expectations = df[(df['CodeKata Score']>10000) & (df['CodeKata Score']<15000)]
Reached_expectations
# Out:
#                 Name  python  mysql  Previous Geekions  \
# 3        Mugunthan S     100     47              10610
# 1            Chandru       0      0              14150
# 2  Ganesh Ramkumar R      -1     24               8790
# 3    Bodipudi Harini      -1     35              10040
#
#    computational_thinking  CodeKata Score  \
# 3                       0           10610
# 1                       0           14490
# 2                       6           10790
# 3                      -1           10040
#
#                                   Department  Rising  python_en
# 3           Computer Science and Engineering       0        NaN
# 1           Computer Science and Engineering     340       20.0
# 2           Computer Science and Engineering    2000       55.0
# 3  Electronics and Communication Engineering       0        0.0

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
Needs_Improvement = df[(df['CodeKata Score']>7000) & (df['CodeKata Score']<10000)]
Needs_Improvement
# Out:
#                       Name  python  mysql  Previous Geekions  \
# 4              Sathammai.S     100      8               8980
# 5             NIVEESHWAR S     100      0               8200
# 6            KALAIARASAN K      85     47               7750
# 7     MOHAMED ZUBAIR AHMED      82      4               7020
# 4                VIINU V P      -1     24               9150
# 5               Poojitha Y       0     35               7210
# 6   Gowtham Chandrasekaran      -1      0               7250
# 7                Gowtham R      -1      4               8650
# 8                 shifak N      58      0               5180
# 9                  Balaji       -1     20               6170
# 10                Rushitha      -1     62               7470
# 11    Balaraman Muthupandi      -1      0               7670
# 12                JPradhap     100      0               7340
# 13           SRIRAMKUMAR B      -1      0               6400
# ...

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
Unsatisfactory = df[df['CodeKata Score']<7000]
Unsatisfactory
# Out:
#                Name  python  mysql  Previous Geekions  computational_thinking  \
# 8        J.SUGANTHI      27     50               5860                       0
# 9      thamizhpaana      29      0               5500                       0
# 10  Iyappan Samiraj      50     24               5400                       0
# 11     Ponniyamma.R     100     11               5380                       0
# 12        SABAPATHI     100      0               5280                       0
# ..              ...     ...    ...                ...                     ...
# 30    praveen raj j      24      0               2380                       0
# 31       AMARNATH D      -1     12               1890                      -1
# 32             bala      32      0               1720                      -1
# 33             XY Z      -1     -1                  0                      -1
# 34        Hariharan      -1     -1                  0                       0
#
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
Previous_Geekions_Avg = df['Previous Geekions'].mean()
Previous_Geekions_Avg
# Out:
# 3842.3529411764707

# %%
CodeKata_Score_Avg = df['CodeKata Score'].mean()
CodeKata_Score_Avg
# Out:
# 4051.764705882353

# %%
x= ('Previous_Geekions_Avg', 'CodeKata_Score_Avg ')
y = np.arange(len(x))
avg = [3842.3529411764707,4051.764705882353]

plt.bar(y,avg, align='center', alpha=0.7)
plt.xticks(y,x)
plt.ylabel("Average")
plt.title('Average of previous week geekions vs codekata score')

plt.show()

# %% [markdown]
# ###### No of students participated

# %%
No_of_students_participated = df.shape[0]
print("No of students participated :", No_of_students_participated)
# Out:
# No of students participated : 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
x = df['python'].mean()
y = df['mysql'].mean()
z = df['python_en'].mean()
print("Average completion of python course or my_sql or python english or computational thinking :",x,y,z)
# Out:
# Average completion of python course or my_sql or python english or computational thinking : 54.34453781512605 23.478991596638654 29.65714285714286

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df.sort_values(by=["Rising"],axis=0,ascending=False).head(3)
# Out:
#                  Name  python  mysql  Previous Geekions  \
# 8            shifak N      58      0               5180
# 18     Narasimhan Y L      -1      0               4800
# 2   Ganesh Ramkumar R      -1     24               8790
#
#     computational_thinking  CodeKata Score  \
# 8                        0            8320
# 18                       0            6800
# 2                        6           10790
#
#                                 Department  Rising  python_en
# 8   Electronics and Electrical Engineering    3140        0.0
# 18        Computer Science and Engineering    2000       -1.0
# 2         Computer Science and Engineering    2000       55.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df.sort_values(by=["Previous Geekions"],axis=0,ascending=False).head(3)
# Out:
#           Name  python  mysql  Previous Geekions  computational_thinking  \
# 0    A.Dharani      82     20              24500                       0
# 1  V.JEEVITHA       82     20              21740                       0
# 2  HEMAVATHI.R     100    100              19680                       0
#
#    CodeKata Score                        Department  Rising  python_en
# 0           24500  Computer Science and Engineering       0        NaN
# 1           21740  Computer Science and Engineering       0        NaN
# 2           19680  Computer Science and Engineering       0        NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
dept = df.groupby('Department')['CodeKata Score'].sum()
dept
# Out:
# Department
# Computer Science and Engineering             320025
# Electronics and Communication Engineering    108335
# Electronics and Electrical Engineering        53800
# Name: CodeKata Score, dtype: int64

# %%
dept.plot.pie(autopct="%.1f%%")
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
toppers = df.groupby('Department')['Name','Department','CodeKata Score'].max()
toppers
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                                      Name  \
# Department
# Computer Science and Engineering              vijayakumar
# Electronics and Communication Engineering       vignesh B
# Electronics and Electrical Engineering     yaser ahamed.A
#
#                                                                           Department  \
# Department
# Computer Science and Engineering                    Computer Science and Engineering
# Electronics and Communication Engineering  Electronics and Communication Engineering
# Electronics and Electrical Engineering        Electronics and Electrical Engineering
#
#                                            CodeKata Score
# Department
# Computer Science and Engineering                    24500
# ...

# %%
sns.barplot(x = 'Name',y = 'CodeKata Score' ,hue='Department',data=toppers)
